# %%
import numpy as np
import matplotlib.pyplot as plt
OmegaCDM = 0.3

# %%
data_atr = np.loadtxt('rhoDMatr.dat')
data_tau = np.loadtxt('rhoDMtau.dat')

# %%
fatr = np.log(data_atr[:,0])
tauatr = data_atr[:,1]
Neffatr = data_atr[:,2]
Omegadiffatr = data_atr[:, 3]
ftau = np.log(data_tau[:,0])
atrtau = data_tau[:,1]
Nefftau = data_tau[:, 2]
Omegadifftau = data_tau[:, 3]

# %%
fig1, (Ntau, difftau) = plt.subplots(1,2, figsize = (10,6))
Ntau.tricontourf(ftau, atrtau, Nefftau, levels = 10)
#Ntau.set_xscale('log')
Ntau.set_yscale('log')
Ntau.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
Ntau.set_ylabel(r'$\tau$ (years)')
Ntau.set_title(r'$N_{eff}$, $a_{tr} = 1/(1+1100)$')
Ntau.axhline(378000, color='k', linestyle='--')
fig1.colorbar(Ntau.tricontourf(ftau, atrtau, Nefftau, levels = 10), ax=Ntau,
                     orientation='horizontal').set_label(r'$\Delta N_{eff}$')

difftau.tricontourf(ftau, atrtau, Omegadifftau/OmegaCDM, levels = 10)
#difftau.set_xscale('log')
difftau.set_yscale('log')
difftau.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
difftau.set_ylabel(r'$\tau$ (years)')
difftau.set_title(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$, $a_{tr} = 1/(1+1100)$')
difftau.axhline(378000, color='k', linestyle='--')
fig1.colorbar(difftau.tricontourf(ftau, atrtau, Omegadifftau/OmegaCDM, levels = 10), ax=difftau,
                     orientation='horizontal').set_label(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$')

fig1.tight_layout()

# %%
fig2, (Natr, diffatr) = plt.subplots(1,2, figsize = (10,6))
Natr.tricontourf(fatr, tauatr, Neffatr, levels = 10)
#Natr.set_xscale('log')
Natr.set_yscale('log')
Natr.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
Natr.set_ylabel(r'$atr$')
Natr.set_title(r'$N_{eff}$, $\tau = 378,000$ years')
Natr.axhline(1/(1101), color='k', linestyle='--')
fig2.colorbar(Natr.tricontourf(fatr, tauatr, Neffatr, levels = 10), ax=Natr,
                     orientation='horizontal').set_label(r'$\Delta N_{eff}$')

diffatr.tricontourf(fatr, tauatr, Omegadiffatr/OmegaCDM, levels = 10)
#diffatr.set_xscale('log')
diffatr.set_yscale('log')
diffatr.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
diffatr.set_ylabel(r'$atr$')
diffatr.set_title(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$, $\tau = 378,000$ years')
diffatr.axhline(1/(1101), color='k', linestyle='--')
fig2.colorbar(diffatr.tricontourf(fatr, tauatr, Omegadiffatr/OmegaCDM, levels = 10), ax=diffatr,
                     orientation='horizontal').set_label(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$')

fig2.tight_layout()

# %%
Omegadiffatr/OmegaCDM
# Out:
# array([1.09183853, 1.06251167, 1.02004568, 0.95967839, 1.09194392,
#        1.06261435, 1.02014447, 0.95977169, 1.09205948, 1.06272694,
#        1.0202528 , 0.95987399, 1.09218618, 1.0628504 , 1.02037157,
#        0.95998617, 1.09232512, 1.06298576, 1.0205018 , 0.96010916,
#        1.09247745, 1.06313418, 1.0206446 , 0.96024402, 1.09264448,
#        1.06329693, 1.02080118, 0.96039189, 1.09282763, 1.06347537,
#        1.02097286, 0.96055403, 1.09302845, 1.06367103, 1.02116111,
#        0.96073181, 1.09324864, 1.06388557, 1.02136752, 0.96092675,
#        1.09349008, 1.06412081, 1.02159384, 0.96114049, 1.09375481,
#        1.06437874, 1.021842  , 0.96137486, 1.09404508, 1.06466156,
#        1.0221141 , 0.96163183, 1.09436336, 1.06497166, 1.02241246,
#        0.9619136 , 1.09471234, 1.06531168, 1.0227396 , 0.96222256,
#        1.09509499, 1.06568451, 1.0230983 , 0.96256133, 1.09551456,
#        1.06609331, 1.02349161, 0.96293278, 1.09597461, 1.06654155,
#        1.02392287, 0.96334007, 1.09647905, 1.06703303, 1.02439574,
#        0.96378666, 1.09703215, 1.06757194, 1.02491423, 0.96427634,
#        1.09763862, 1.06816284, 1.02548275, 0.96481327, 1.0983036 ,
#        1.06881075, 1.02610612, 0.96540201, 1.09903274, 1.06952117,
#        1.02678964, 0.96604755, 1.09983222, 1.07030013, 1.0275391 ,
#        0.96675538, 1.07115425, 1.02836088, 0.96753151, 1.07209078,
#        1.02926195, 0.96838253, 1.07311767, 1.03024996, 0.96931567,
#        1.07424363, 1.0313333 , 0.97033886, 1.07547824, 1.03252118,
#        0.97146078, 1.07683196, 1.03382367, 0.97269096, 1.0783163 ,
#        1.03525184, 0.97403986, 1.07994386, 1.03681782, 0.97551893,
#        1.08172845, 1.0385349 , 0.97714074, 1.08368524, 1.04041768,
#        0.97891907, 1.08583084, 1.04248214, 0.98086903, 1.08818346,
#        1.04474582, 0.98300719, 1.09076309, 1.04722794, 0.98535173,
#        1.09359164, 1.0499496 , 0.98792256, 1.09669313, 1.05293392,
#        0.99074155, 1.05620624, 0.99383266, 1.05979439, 0.99722217,
#        1.06372884, 1.00093891, 1.06804303, 1.00501449, 1.07277364,
#        1.0094836 , 1.07796088, 1.01438424, 1.08364884, 1.01975814,
#        1.08988589, 1.02565105, 1.09672507, 1.03211314, 1.03919946,
#        1.04697039, 1.05549216, 1.06483745])
