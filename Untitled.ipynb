# %%
import numpy as np
import matplotlib.pyplot as plt
OmegaCDM = 0.3

# %%
data_atr = np.loadtxt('rhoDMatr.dat')
data_tau = np.loadtxt('rhoDMtau.dat')

# %%
fatr = np.log(data_atr[:,0])
tauatr = data_atr[:,1]
Neffatr = data_atr[:,2]
Omegadiffatr = data_atr[:, 3]
ftau = np.log(data_tau[:,0])
atrtau = data_tau[:,1]
Nefftau = data_tau[:, 2]
Omegadifftau = data_tau[:, 3]

# %%
fig1, (Ntau, difftau) = plt.subplots(1,2, figsize = (10,6))
Ntau.tricontourf(ftau, atrtau, Nefftau, levels = 10)
#Ntau.set_xscale('log')
Ntau.set_yscale('log')
Ntau.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
Ntau.set_ylabel(r'$\tau$ (years)')
Ntau.set_title(r'$N_{eff}$, $a_{tr} = 1/(1+1100)$, Both constrained')
Ntau.axhline(378000, color='k', linestyle='--')
fig1.colorbar(Ntau.tricontourf(ftau, atrtau, Nefftau, levels = 10), ax=Ntau,
                     orientation='horizontal').set_label(r'$\Delta N_{eff}$')

difftau.tricontourf(ftau, atrtau, Omegadifftau, levels = 20)
#difftau.set_xscale('log')
difftau.set_yscale('log')
difftau.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
difftau.set_ylabel(r'$\tau$ (years)')
difftau.set_title(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$, $a_{tr} = 1/(1+1100)$, Both constrained')
difftau.axhline(378000, color='k', linestyle='--')
fig1.colorbar(difftau.tricontourf(ftau, atrtau, Omegadifftau, levels = 10), ax=difftau,
                     orientation='horizontal').set_label(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$')

fig1.tight_layout()

# %%
fig2, (Natr, diffatr) = plt.subplots(1,2, figsize = (10,6))
Natr.tricontourf(fatr, tauatr, Neffatr, levels = 10)
#Natr.set_xscale('log')
Natr.set_yscale('log')
Natr.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
Natr.set_ylabel(r'$atr$')
Natr.set_title(r'$N_{eff}$, $\tau = 378,000$ years, Both constrained')
Natr.axhline(1/(1101), color='k', linestyle='--')
fig2.colorbar(Natr.tricontourf(fatr, tauatr, Neffatr, levels = 10), ax=Natr,
                     orientation='horizontal').set_label(r'$\Delta N_{eff}$')

diffatr.tricontourf(fatr, tauatr, Omegadiffatr, levels = 20)
#diffatr.set_xscale('log')
diffatr.set_yscale('log')
diffatr.set_xlabel(r'$\log(\rho_{\mathrm{DM}}^{\mathrm{init}})$')
diffatr.set_ylabel(r'$atr$')
diffatr.set_title(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$, $\tau = 378,000$ years, Both constrained')
diffatr.axhline(1/(1101), color='k', linestyle='--')
fig2.colorbar(diffatr.tricontourf(fatr, tauatr, Omegadiffatr, levels = 10), ax=diffatr,
                     orientation='horizontal').set_label(r'$\Omega_{\mathrm{decay}} / \Omega_{\mathrm{observed}}$')

fig2.tight_layout()

# %%
Omegadiffatr
# Out:
# array([1.01804513, 0.99069928, 0.95110161, 1.01805757, 0.9907114 ,
#        0.95111327, 1.01807152, 0.990725  , 0.95112635, 1.01808718,
#        0.99074026, 0.95114103, 1.01810475, 0.99075738, 0.9511575 ,
#        1.01812447, 0.99077659, 0.95117598, 1.01814659, 0.99079814,
#        0.95119672, 1.01817141, 0.99082232, 0.95121998, 1.01819926,
#        0.99084946, 0.95124609, 1.0182305 , 0.9908799 , 0.95127538,
#        1.01826556, 0.99091406, 0.95130824, 1.0183049 , 0.99095238,
#        0.95134511, 1.01834903, 0.99099539, 0.95138649, 1.01839856,
#        0.99104364, 0.95143291, 1.01845412, 0.99109777, 0.951485  ,
#        1.01851647, 0.99115852, 0.95154344, 1.01858642, 0.99122667,
#        0.95160901, 1.0186649 , 0.99130314, 0.95168258, 1.01875297,
#        0.99138894, 0.95176513, 1.01885178, 0.99148522, 0.95185776,
#        1.01896264, 0.99159323, 0.95196168, 1.01908704, 0.99171443,
#        0.95207829, 1.01922661, 0.99185042, 0.95220912, 1.01938321,
#        0.992003  , 0.95235592, 1.01955892, 0.9921742 , 0.95252063,
#        1.01975607, 0.99236629, 0.95270544, 1.01997728, 0.99258181,
#        0.9529128 , 1.02022548, 0.99282364, 0.95314546, 1.02050396,
#        0.99309497, 0.95340651, 1.02081642, 0.99339941, 0.95369942,
#        1.02116701, 0.993741  , 0.95402806, 1.02156038, 0.99412427,
#        0.95439681, 1.02200175, 0.9945543 , 0.95481055, 1.02249697,
#        0.99503681, 0.95527478, 1.02305263, 0.9955782 , 0.95579566,
#        1.02367608, 0.99618564, 0.9563801 , 1.0243756 , 0.99686721,
#        0.95703585, 0.90041582, 1.02516048, 0.99763194, 0.95777162,
#        0.90111071, 1.02604114, 0.99848999, 0.95859718, 0.9018904 ,
#        1.02702925, 0.99945275, 0.95952347, 0.90276524, 1.02813794,
#        1.00053298, 0.9605628 , 0.90374684, 1.0293819 , 1.00174502,
#        0.96172896, 0.90484824, 1.03077766, 1.00310497, 0.96303743,
#        0.90608405, 1.03234374, 1.00463087, 0.96450558, 0.90747069,
#        1.03410091, 1.00634297, 0.96615289, 0.90902657, 1.03607251,
#        1.00826399, 0.96800123, 0.91077234, 1.03828468, 1.01041944,
#        0.97007515, 0.91273119, 1.0407668 , 1.01283792, 0.97240216,
#        0.91492913, 1.0435518 , 1.01555154, 0.97501318, 0.91739537,
#        1.04667665, 1.01859631, 0.97794287, 0.92016266, 1.05018282,
#        1.02201266, 0.98123013, 0.92326777, 1.05411685, 1.02584593,
#        0.98491862, 0.92675196, 1.05853095, 1.03014702, 0.98905732,
#        0.93066155, 1.06348372, 1.03497304, 0.99370121, 0.93504849,
#        1.0690409 , 1.04038807, 0.99891199, 0.93997112, 1.07527627,
#        1.046464  , 1.00475888, 0.94549491, 1.08227258, 1.05328154,
#        1.01131958, 0.95169334, 1.09012274, 1.06093122, 1.01868129,
#        0.95864888, 1.09893097, 1.06951465, 1.02694186, 0.96645414,
#        1.07914587, 1.03621114, 0.97521303, 1.08995284, 1.04661239,
#        0.98504225, 1.05828399, 0.99607281, 1.07138124, 1.08607848])
