# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

H0 =

# %%
def H(x, rho):
    rhotot = sum(rho) + 

def f(x, rho):
    return [-3*rho[0] - ]

# %%
data = np.loadtxt('scan.dat')

# %%
f = data[:,0]
tau = data[:,1]
Neff = data[:, 2]

# %%
plt.tricontourf(f, tau, Neff, levels=1000, norm = LogNorm())  # 100 contour levels for smoothness
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$f_{DDM}$')
plt.ylabel(r'$\tau$ (years)')
plt.title(r'$N_{eff}$')
plt.axhline(378000, color='k', linestyle='--')
plt.tight_layout()
